# %%
print ("Hello world ")
# Out:
# Hello world

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("D:\mini project\IRIS.csv")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df0 = df[df.sepal_length == 0]
df1 = df[df.sepal_width == 1]
df2 = df[df.petal_length == 2]
df3 = df[df.petal_width	 == 3]

# %%
df2.isnull().sum()
# Out:
# sepal_length    0.0
# sepal_width     0.0
# petal_length    0.0
# petal_width     0.0
# species         0.0
# dtype: float64

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  0 non-null      float64
#  1   sepal_width   0 non-null      float64
#  2   petal_length  0 non-null      float64
#  3   petal_width   0 non-null      float64
#  4   species       0 non-null      object
# dtypes: float64(4), object(1)
# memory usage: 0.0+ bytes

# %%
df2.shape
# Out:
# (0, 5)

# %%
sns.catplot(x = 'sepal_length', y = 'species' , data = df)

# %%
sns.histplot(x = 'sepal_width', data = df , hue = 'species',kde= True)
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='Count'>

# %%
sns.lineplot(x = df.sepal_length , y = df.sepal_width , hue= df.species)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
 x = df.iloc[:,:4]
 y = df.species 
y
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: species, Length: 150, dtype: object

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state= 10)
y_train.shape
# Out:
# (105,)

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
model = SVC(kernel= 'rbf' , gamma = 0.8 , C= 1)
model.fit(x_train, y_train)
print(model.get_params())
# Out:
# {'C': 1, 'break_ties': False, 'cache_size': 200, 'class_weight': None, 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 0.8, 'kernel': 'rbf', 'max_iter': -1, 'probability': False, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}

# %%
model.score(x,y)
# Out:
# 0.9866666666666667
